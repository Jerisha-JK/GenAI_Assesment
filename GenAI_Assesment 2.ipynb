# %% [markdown]
# ### Send a Simple API Call Using Python Requests
# ## Write a Python script that:
# * reads a text input from the command line
# * sends it to Grok API
# * prints the response

# %%
from groq import Groq

client = Groq(api_key = "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")

input_prompt = input("Enter a command")

response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system" , "content":"You are programm command reader"},
        {"role":"user","content":input_prompt}
    ],
    max_tokens = 250,
    temperature = 0,
)

print(response.choices[0].message.content)
# Out:
# Enter a command add two numbers
# To add two numbers, I'll need you to provide the numbers. You can enter them like this:
#
# `num1 + num2`
#
# For example:
#
# `2 + 3`
#
# Please enter the numbers you'd like to add.

# %%
from groq import Groq

client = Groq(api_key = "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")

def prompt_template(role,topic):
    response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system" , "content":role},
        {"role":"user","content":topic}
    ],
    max_tokens = 250,
    temperature = 0,
   )
    
    print(response.choices[0].message.content)
    return response.choices[0].message.content

role = input("Enter a role:")
topic = input("Enter a topic:")
result = prompt_template(role,topic)
print("Formatted Output:",result)
# Out:
# Enter a role: blogger
# Enter a topic: food
# Food is a universal language that brings people together. Here are some interesting facts and topics related to food:
#
# 1. **Culinary Trends**: What's popular in the food world right now? Some current trends include plant-based eating, sustainable seafood, and international cuisine.
# 2. **Recipe Ideas**: Looking for inspiration for your next meal? I can suggest some delicious and easy-to-make recipes, from classic comfort food to exotic international dishes.
# 3. **Food and Culture**: Food is often deeply rooted in a culture's history and traditions. Let's explore the significance of food in different cultures and how it brings people together.
# 4. **Nutrition and Wellness**: What are the health benefits of different foods? How can you make informed choices about the food you eat to support your well-being?
# ...

# %%
from groq import Groq

client = Groq(api_key = "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")

def prompt_template(topic):
    for i in topic:
        messages = [
        {"role":"system" , "content":"You are a chatbot who answers all the question"},
        {"role":"user","content":i}
        ]

    
    response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = messages,
    max_tokens = 250,
    temperature = 0,
    )
    
    print(response.choices[0].message.content)
    return response.choices[0].message.content


topic = [
    "What is LLM",
    "Define Global warming",
    "Why is this always crowded",
    "Is AI is emerging technology",
    "Mention the purpose of Groq"
]

# for i in topic:
#     messages = [
#         {"role":"system" , "content":"You are a chatbot who answers all the question"},
#         {"role":"user","content":i}
#     ]
    
#     output = response.choices[0].message.content

result = prompt_template(topic)
print("Formatted Output:",result)
# Out:
# Groq is a US-based technology company that specializes in developing and manufacturing high-performance AI computing hardware and software. The primary purpose of Groq is to accelerate the development and deployment of artificial intelligence (AI) and machine learning (ML) applications.
#
# Groq's main goal is to provide a scalable and efficient platform for AI computing, enabling organizations to build and train large-scale AI models quickly and cost-effectively. Their technology is designed to address the growing demand for AI computing power, which is becoming increasingly important in various industries such as healthcare, finance, and autonomous vehicles.
#
# Some of the key purposes of Groq include:
#
# 1. **Accelerating AI model training**: Groq's hardware and software solutions are designed to speed up the training of large-scale AI models, reducing the time and cost associated with this process.
# ...

# %%
from groq import Groq

client = Groq(api_key = "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")


rule = {
    "heading" : " ",
    "points" : []
}

response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":"Generate JSON formatted text"},
        {"role":"user","content":"What does mean by python"},
        {"role":"assistant","content":f"The answer should be in {rule} format"}
    ],
        
        
    max_tokens = 250,
    temperature = 0,
    )
    
print(response.choices[0].message.content)
# Out:
# .
#
# {
#   "heading": "What is Python?",
#   "points": [
#     "Python is a high-level, interpreted programming language.",
#     "It was created in the late 1980s by Guido van Rossum.",
#     "Python is known for its simplicity, readability, and ease of use.",
#     "It is often used for web development, scientific computing, data analysis, artificial intelligence, and more.",
#     "Python is a versatile language that can be used for a wide range of applications, from small scripts to large-scale enterprise systems."
#   ]
# }

# %% [markdown]
# ### Build a Python Summarizer With Word Count Limit
# ## User pastes text → you count words → send to Grok API → ask for half of the length summary.

# %%
from groq import Groq

client = Groq(api_key = "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")


# rule = {
#     "heading" : " ",
#     "points" : []
# }

response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":"Generate JSON formatted text"},
        {"role":"user","content":"What does mean by python"},
        {"role":"assistant","content":f"The answer should be in {rule} format"}
    ],
        
        
    max_tokens = 250,
    temperature = 0,
    )
    
print(response.choices[0].message.content)

# %%
from groq import Groq

client = Groq(api_key = "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")

language = input("Enter a Language(Tamil, Hindi, Malayalam):")
prompt = input("Enter a word to translate:")
    

response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":"You are a translator"},
        {"role":"user","content":prompt},
        {"role":"assistant","content":f"Translate the {prompt} based on selected language{language}"}
    ],
        
        
    max_tokens = 250,
    temperature = 0,
    )
    
print(response.choices[0].message.content)
# Out:
# Enter a Language(Tamil, Hindi, Malayalam): tamil
# Enter a word to translate: good
# : நன்றி
# hindi: अच्छा
# spanish: bueno
# french: bon
# german: gut
# italian: buono
# portuguese: bom
# russian: хороший
# chinese: 好

# %%
from groq import Groq

client = Groq(api_key = "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")

memory = []

def groq_api(prompt,memory):
    response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":"You are a chatbot"},
        {"role":"user","content":prompt},
        # {"role":"assistant","content":f"The answer should be in {rule} format"}
    ],
        
        
    max_tokens = 250,
    temperature = 0,
    )
    print(response.choices[0].message.content)
    return response.choices[0].message.content


for i in range(3):
    prompt = input("Enter a prompt:")
    respond = groq_api(prompt,memory)
    memory.append(respond)
    print("Full History:\n",memory)
# Out:
# Enter a prompt: rear
# It seems like you've entered a word. Here are a few possible meanings or associations with "rear":
#
# 1. Back or hind part of something: The rear of the car was damaged in the accident.
# 2. To follow or come after: The team will rear the leaders in the competition.
# 3. To bring up or raise (animals): The farmer will rear the calves on the farm.
# 4. In a military context, the rear is the area behind the main fighting forces.
#
# If you could provide more context or clarify what you're looking for, I'd be happy to help further.
# Full History:
# ...

# %%
from groq import Groq

client = Groq(api_key = "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")



with open("swap_num.py","r") as f:
    content = f.read()
    print(content)

response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":"You are a debugger"},
        {"role":"user","content":f"find error in {f} file"},
        {"role":"assistant","content":f"Generate improved code from the file in an JSON format"}
    ],
        
        
    max_tokens = 1450,
    temperature = 0,
    
    )
    
print(response.choices[0].message.content)
# Out:
# a = 12
# b = 34
#
# a,b = b,a
# print("a is:",a)
# print("b is:",b)
# .
#
# ```json
# {
#   "file": "<_io.TextIOWrapper name='swap_num.py' mode='r' encoding='cp1252'>",
#   "errors": [
#     {
#       "line": 1,
#       "column": 1,
#       "message": "SyntaxError: unexpected EOF while parsing",
#       "description": "The file is empty or has a syntax error."
#     }
#   ]
# }
# ```
#
# However, without the actual code in the file, it's difficult to pinpoint the exact error.
#
# Here are some common errors that might occur in a Python file:
#
# 1. **Indentation Error**: Python uses indentation to denote block-level structure. If the indentation is incorrect, it can cause a syntax error.
#
# 2. **Syntax Error**: Python has a specific syntax that must be followed. If the syntax is incorrect, it can cause a syntax error.
#
# 3. **NameError**: This error occurs when a variable or function is used before it is defined.
#
# ...

# %%
from groq import Groq

client = Groq(api_key = "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")



prompt = input("Enter a prompt:")
temp = float(input("Enter a temperature value:"))
# role = input("Enter a role (system/user/assistant):")



response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":"Your are Prompt Playground Simulator"},
        {"role":"user","content":prompt}
    ],
        
        
    max_tokens = 1450,
    temperature = temp,
    
    )
# print(response)   
print(response.choices[0].message.content)
# Out:
# Enter a prompt: What is earthquake
# Enter a temperature value: 0.5
# **Earthquake: A Seismic Event**
#
# An earthquake is a sudden, rapid shaking of the Earth's surface caused by the release of energy stored in the Earth's lithosphere. This energy release creates seismic waves that can cause the ground to shake, sometimes violently, and can lead to damage to structures, landscapes, and the environment.
#
# **Causes of Earthquakes:**
#
# 1. **Tectonic Plate Movement:** Earthquakes are often caused by the movement of tectonic plates in the Earth's lithosphere. These plates are in constant motion, sometimes sliding past each other, sometimes colliding, and sometimes pulling apart. This movement can create stress in the Earth's crust, which is released as seismic waves when the stress becomes too great.
# 2. **Volcanic Activity:** Volcanic eruptions can also cause earthquakes, as the movement of magma and gas beneath the surface of the Earth can create seismic waves.
# ...

# %%
from groq import Groq

client = Groq(api_key = "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")



topic = input("Enter a topic:")
notes_length = input("Enter a Length(short/medium/long):")





response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":"Your are Notes Generator"},
        {"role":"user","content":topic},
        {"role":"assistant","content":f"Notes should follow the {notes_length} for limiting contents"}
    ],
        
        
    max_tokens = 1450,
    temperature = temp,
    
    )


content = response.choices[0].message.content
# print(content)
with open("example.txt","a") as f:
    f.write(content)
# Out:
# Enter a topic: global
# Enter a Length(short/medium/long): medium

# %%
from groq import Groq

client = Groq(api_key = "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")



topic = input("Enter a topic:")
notes_length = input("Enter a Length(short/medium/long):")





response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":"Your are Notes Generator"},
        {"role":"user","content":topic},
        {"role":"assistant","content":f"Notes should follow the {notes_length} for limiting contents"}
    ],
        
        
    max_tokens = 1450,
    temperature = temp,
    
    )


content = response.choices[0].message.content
print(content)
with open("example.txt","a") as f:
    f.write(content)

# %%
from groq import Groq

client = Groq(api_key = "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")
domain = input("Choose a domain(medical, travel, code):")
topic = input("Enter a topic:")

response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":f"You are a {domain}"},
        {"role":"user","content":topic},
        {"role":"assistant","content":f"the system generate answer based on chosen {domain}"}
    ],
        
        
    max_tokens = 1450,
    temperature = 0.3,
    
    )
content = response.choices[0].message.content
print(content)
# Out:
# Choose a domain(medical, travel, code): code
# Enter a topic: iraq
# .
#
# for 'iraq', the system generate answer as follows:
#
# I - Intelligence
# R - Resilience
# A - Ambitious
# Q - Quirky
#
# These are the first letters of the words that describe Iraq.

# %%
from groq import Groq

client = Groq(api_key = "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")
# domain = input("Choose a domain(medical, travel, code):")
topic = input("Enter a topic:")

response = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system","content":"You are a deep thinker with high reasoning person "},
        {"role":"user","content":topic},
        {"role":"assistant","content":f"It should generate contain defining the {topic} and reasoning and make the answer in shorter"}
    ],
        
        
    max_tokens = 1450,
    temperature = 0.3,
    
    )
content = response.choices[0].message.content
print(content)
# Out:
# Enter a topic: travel
#  format.
#
# Travel:
# - A journey from one place to another,
# - Can be physical or metaphorical,
# - Often involves movement, exploration, and discovery.
#
# Reasons for Travel:
#
# 1. **Cultural Exchange**: To learn about different cultures, traditions, and ways of life.
# 2. **Personal Growth**: To challenge oneself, step out of comfort zones, and develop new skills.
# 3. **Relaxation and Leisure**: To unwind, recharge, and enjoy new experiences.
# 4. **Adventure and Exploration**: To discover new places, try new activities, and experience thrill.
# 5. **Business and Networking**: To attend conferences, meet new people, and expand professional networks.
#
# Types of Travel:
#
# 1. **Domestic Travel**: Within one's own country.
# 2. **International Travel**: Across national borders.
# 3. **Solo Travel**: Traveling alone.
# 4. **Group Travel**: Traveling with others, such as friends, family, or tour groups.
# ...
